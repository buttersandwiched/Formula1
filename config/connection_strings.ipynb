# %%
acct_name = "fs.azure.account.key.databrickssandbox202307.dfs.core.windows.net",
acct_key = dbutils.secrets.get("arittle-data-scope", "databrickssandbox202307-acct-key")
sas_key = dbutils.secrets.get("arittle-data-scope", "formula1-sas-key")
spark.conf.set( str(acct_name), str(acct_key) )

# %%
dropzone_container = "abfss://dropzone@databrickssandbox202307.dfs.core.windows.net/formula1"
raw_container = "abfss://datalakehouse@databrickssandbox202307.dfs.core.windows.net/schemas/formula1/raw"
curated_container = "abfss://datalakehouse@databrickssandbox202307.dfs.core.windows.net/schemas/formula1/curated"
